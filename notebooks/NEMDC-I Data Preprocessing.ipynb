# %% [markdown]
# # NEM DATA CHALLENGE
# ## Data Preprocessing Code
#
# * Rev001 Save csv's generated by each function at different subdirs
# * Rev002 Outputs all files into one single subdir
# * Rev005 A pandas dataframe is used in def: F2 to write to disk instead of dask.dataframe, as in previous versions. Also, F4 has been merged into F3. These changes have reduced run-time to about 5.5 hrs.

# %%
import os
import time
import numpy as np
import pandas as pd
import dask.dataframe as dd
from datetime import datetime

# %%
def main():
    '''Dataset Preprocessing Main module'''

    # call to Defs
    F1_csv_per_asset()
    F2_csv_per_sensor()
    F3_csv_resample()
    df = F4_all_in_one_csv()
    return df

# %%
def read_translations():
    '''Read translations.csv, which has been previously converted from the original XML format by 
    reading the file in (microsoft) PowerBI and exporting to csv'''
    
    in_path = os.getcwd()
    in_file = 'translations.csv'
    in_csv  = os.path.join(in_path,in_file)
    df_trans = pd.read_csv(in_csv)
    assets = df_trans.asset.unique()
    sensors = df_trans.sensorID.unique()
    return assets, sensors, df_trans

# %%
def F1_csv_per_asset():
    '''Reads original dataset.csv file and divides it into a csv file per Asset. 
    Additionally, it translates Asset_variables into Unified Sensor IDs.'''
    
    t0 = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    print("Executing F1_csv_asset at {}".format(t0))
    # FUN.CALL define in/output dirs
    out_path = files_location()
    in_path  = os.getcwd()
    # FUN.CALL read_translations
    assets, sensors, df_trans = read_translations()

    # read principal dataset
    in_file = 'dataset.csv'
    in_csv=os.path.join(in_path,in_file)
    ddf = dd.read_csv(in_csv)
    
    # translate asset variables into unified sensor ID
    ddf = ddf.merge(df_trans, how='inner', on=['asset', 'variable'])
    ddf = ddf.drop('variable', axis=1)
    
    # loop over the dataset and separate rows per asset
    for asset in assets:
        t0 = time.time()
        mask = (ddf['asset']==asset)
        ddf_asset = ddf[mask].drop(['asset'], axis=1)
        # write to disk
        out_file = 'F1-'+ asset +'-*.csv'
        out_csv=os.path.join(out_path,out_file)
        dd.to_csv(ddf_asset,out_csv, index=False)
        t1 = time.time()
        print("File {} has been written in {}".format(asset, t1-t0))
        #break #<== remove firts # for code testing, allows one loop only
    
    # FUN.CALL Remove files with no data created by dask.dataframe during dd.to_csv
    remove_empty_files(out_path)

# %%
def F2_csv_per_sensor():
    '''F2 reads each csv file generated by F1 and further divides them into one csv file per SensorID, 
    rendering a total of 140 individual csv files (5 assets * 28 sensorsIDs)'''

    t0 = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    print("Executing F2:csv_sensor at {}".format(t0))
    # FUN.CALL
    out_path = files_location()
    in_path  = out_path # modify if in/out-paths differ 
    # FUN.CALL
    assets, sensors, df_trans = read_translations() 
        
    for asset in assets:
        in_file = 'F1-'+ asset + '-*.csv'
        in_csv=os.path.join(in_path,in_file)
        ddf = dd.read_csv(in_csv)
        
        for idx, sensor in enumerate(sensors, start=1):
            t0 = time.time()
            mask = (ddf['sensorID']==sensor)
            ddf_sensor = (ddf[mask].drop(['sensorID'], axis=1)
                                   .rename(columns={'value':sensor})
                                   .compute())
            df = pd.DataFrame(ddf_sensor)
            # write to csv file per asste&sensor
            out_file = 'F2-'+ asset + '-' + sensor + '.csv' 
            out_csv=os.path.join(out_path,out_file)
            df.to_csv(out_csv, index=False)
            t1 = time.time()
            print("File {} has been written in {}".format(asset +'-'+ str(idx), t1-t0))

# %%
def F3_csv_resample():
    '''Resample each csv file to a sampling freq. of 10 min '''
    
    t0 = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    print("Executing F3 csv_resample at {}".format(t0))
    #FUN.CALL
    out_path = files_location()
    in_path  = out_path # modify if in/out-paths differ
    # FUN.CALL
    assets, sensors, df_trans = read_translations() 
       
    for asset in assets:
        ta0 = time.time()
        for idx, sensor in enumerate(sensors, start=1):
            ts0 = time.time()
            in_file = 'F2-'+ asset + '-' + sensor + '.csv' 
            in_csv=os.path.join(in_path,in_file)            
            df = pd.read_csv(in_csv
                             , parse_dates=[['date','time']]
                             , infer_datetime_format=True
                             , index_col='date_time')
            # resample to freq. 10Min  
            df = df.resample('10Min', label='right').mean()
            ts1 = time.time()
            print("Column {} has been resampled in {}".format(str(idx), ts1-ts0))
            # Assemble sensors in df10 dataframe
            if idx == 1: 
                df10 = df.copy()
            else: 
                df10 = pd.concat([df10, df], axis=1)            
        # convert datetime to UNIX Timestamp, as requested by NEM
        df10.index = df10.index.astype(np.int64) // 10**9 
        # write to file
        out_file = 'F3-'+ asset +'.csv' 
        out_csv=os.path.join(out_path,out_file)
        df10.to_csv(out_csv)    
        ta1 = time.time()
        print("Asset {} has been written in {}".format(asset, ta1-ta0))

# %%
def F4_all_in_one_csv():
    '''Concatenate resulting csv files per asset (from F4) into a single csv file
    ready for analysis. Convert index to UNIX Timestamp'''

    t0 = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    print("Executing F4: all_in_one_csv at {}".format(t0))
    # FUN.CALL
    out_path = files_location()
    in_path  = out_path # modify if in/out-paths needed differnt    
    # FUN.CALL
    assets, sensors, df_trans = read_translations() 
    t0 = time.time()
    
    for idx, asset in enumerate(assets, start=1):
        in_file = 'F3-'+ asset + '.csv'
        in_csv = os.path.join(in_path,in_file)
        df_temp = pd.read_csv(in_csv, index_col = 'date_time')
        df_temp['asset'] = asset 
        if idx==1:
            df = df_temp.copy()
        else:
            df = df.append(df_temp)         
    # reorder df columns to show asset as col1
    cols = df.columns.tolist()
    df = df[cols[-1:] + cols[:-1]] 
    out_path=in_path
    out_file = 'datasets10Min.csv' 
    out_csv=os.path.join(out_path,out_file)
    df.to_csv(out_csv)    
    t1 = time.time()
    print("File {} has been written in {}".format(out_file, t1-t0))                 
    return df

# %%
def remove_empty_files(out_path):
    '''Removes empty files created by dash.dataframe during dd.to_csv() operations. 
       Note that os.walk is limited to the top directory with del dirs[:] '''
    
    # out_path = (r'.\OUTPUT') #used for testing
    for (dirname, dirs, files) in os.walk(out_path):
        for filename in files:
            csv_file = os.path.join(dirname,filename)
            filesize = os.path.getsize(csv_file)
            if filesize < 50:
                # print(csvfile, filesize) <== used for code testing
                os.remove(csv_file)
        del dirs[:]

# %%
def files_location():
    '''Defines current working directory and subdir to be used as the output container.
    The code is designed to read the original dataset.csv and translations.cvs files
    from the working directory. The resulting new dataset will be written to the 
    OUTPUT subdir.'''
    
    # Define current working dir., where NEM datasets should be allocated
    cwd = r'C:\Home00Ser\Python\NEM Challenge\datasets'
    os.chdir(cwd)
    # Define results output subdir
    out_path = (r'.\OUTPUT5')
    if not(os.path.isdir(out_path)):
        os.mkdir(out_path)   
    return out_path

# %%
if __name__ == "__main__":
    df = main()
# Out:
# Executing F1_csv_asset at 2017-08-14 23:09:24
# File A001 has been written in 1123.6245002746582
# File A002 has been written in 1124.7763848304749
# File A003 has been written in 1097.8318798542023
# File A004 has been written in 1076.4352734088898
# File A005 has been written in 1031.2572758197784
# Executing F2:csv_sensor at 2017-08-15 00:40:23
# File A001-1 has been written in 101.44135308265686
# File A001-2 has been written in 99.15114951133728
# File A001-3 has been written in 100.98581004142761
# File A001-4 has been written in 98.94102025032043
# File A001-5 has been written in 101.81367754936218
# File A001-6 has been written in 99.61627459526062
# File A001-7 has been written in 99.9220278263092
# File A001-8 has been written in 96.51457715034485
# File A001-9 has been written in 96.23719906806946
# File A001-10 has been written in 101.18718361854553
# File A001-11 has been written in 101.69189262390137
# File A001-12 has been written in 100.61859369277954
# File A001-13 has been written in 100.16742396354675
# File A001-14 has been written in 98.17589235305786
# File A001-15 has been written in 98.3906888961792
# File A001-16 has been written in 99.47084879875183
# File A001-17 has been written in 99.54716086387634
# File A001-18 has been written in 99.94265484809875
# File A001-19 has been written in 98.87032842636108
# File A001-20 has been written in 98.45987391471863
# File A001-21 has been written in 98.81282997131348
# File A001-22 has been written in 100.64028787612915
# File A001-23 has been written in 95.68523859977722
# File A001-24 has been written in 96.64744710922241
# File A001-25 has been written in 98.03261518478394
# File A001-26 has been written in 101.69397211074829
# File A001-27 has been written in 97.3386242389679
# File A001-28 has been written in 98.06743359565735
# File A002-1 has been written in 99.93997979164124
# File A002-2 has been written in 98.88983011245728
# File A002-3 has been written in 98.14837098121643
# File A002-4 has been written in 97.25522375106812
# File A002-5 has been written in 97.59298872947693
# File A002-6 has been written in 99.92101693153381
# File A002-7 has been written in 98.68767833709717
# File A002-8 has been written in 97.61645412445068
# File A002-9 has been written in 97.33357644081116
# File A002-10 has been written in 99.95512747764587
# File A002-11 has been written in 97.92592358589172
# File A002-12 has been written in 98.6275622844696
# File A002-13 has been written in 97.72421860694885
# File A002-14 has been written in 95.70036149024963
# File A002-15 has been written in 96.97567629814148
# File A002-16 has been written in 102.75273966789246
# File A002-17 has been written in 105.2934775352478
# File A002-18 has been written in 180.81427192687988
# File A002-19 has been written in 99.40944957733154
# File A002-20 has been written in 100.21812987327576
# File A002-21 has been written in 98.21419548988342
# File A002-22 has been written in 98.68148374557495
# File A002-23 has been written in 100.23082876205444
# File A002-24 has been written in 100.9941201210022
# File A002-25 has been written in 183.914470911026
# File A002-26 has been written in 168.94493675231934
# File A002-27 has been written in 115.912837266922
# File A002-28 has been written in 172.65145444869995
# File A003-1 has been written in 99.86371541023254
# File A003-2 has been written in 94.32510638237
# File A003-3 has been written in 96.27385878562927
# File A003-4 has been written in 94.440678358078
# File A003-5 has been written in 99.33920168876648
# File A003-6 has been written in 96.49303102493286
# File A003-7 has been written in 97.31580185890198
# File A003-8 has been written in 96.8901777267456
# File A003-9 has been written in 97.7000093460083
# File A003-10 has been written in 98.60881876945496
# File A003-11 has been written in 100.26455879211426
# File A003-12 has been written in 98.43364834785461
# File A003-13 has been written in 99.68261909484863
# File A003-14 has been written in 97.99731826782227
# File A003-15 has been written in 98.6921775341034
# File A003-16 has been written in 96.72224354743958
# File A003-17 has been written in 96.81461691856384
# File A003-18 has been written in 98.15506172180176
# File A003-19 has been written in 99.34714198112488
# File A003-20 has been written in 98.4853150844574
# File A003-21 has been written in 97.63775157928467
# File A003-22 has been written in 98.22245693206787
# File A003-23 has been written in 99.71950101852417
# File A003-24 has been written in 98.53273057937622
# File A003-25 has been written in 97.92143321037292
# File A003-26 has been written in 99.14803528785706
# File A003-27 has been written in 98.8010733127594
# File A003-28 has been written in 98.19489407539368
# File A004-1 has been written in 96.71210026741028
# File A004-2 has been written in 95.96594429016113
# File A004-3 has been written in 97.60293483734131
# File A004-4 has been written in 98.8640193939209
# File A004-5 has been written in 99.69651508331299
# File A004-6 has been written in 101.0230941772461
# File A004-7 has been written in 99.12787628173828
# File A004-8 has been written in 99.26215839385986
# File A004-9 has been written in 100.80335330963135
# File A004-10 has been written in 99.86447358131409
# File A004-11 has been written in 99.45880389213562
# File A004-12 has been written in 99.98883366584778
# File A004-13 has been written in 95.59119772911072
# File A004-14 has been written in 97.50718450546265
# File A004-15 has been written in 96.7547972202301
# File A004-16 has been written in 97.62176775932312
# File A004-17 has been written in 99.65496754646301
# File A004-18 has been written in 100.08677935600281
# File A004-19 has been written in 99.4574556350708
# File A004-20 has been written in 99.959543466568
# File A004-21 has been written in 97.74643230438232
# File A004-22 has been written in 98.95849442481995
# File A004-23 has been written in 100.78772163391113
# File A004-24 has been written in 98.61812543869019
# File A004-25 has been written in 97.34131407737732
# File A004-26 has been written in 97.32253646850586
# File A004-27 has been written in 98.2011570930481
# File A004-28 has been written in 98.33055543899536
# File A005-1 has been written in 97.33702063560486
# File A005-2 has been written in 96.8658492565155
# File A005-3 has been written in 97.42058825492859
# File A005-4 has been written in 97.79182457923889
# File A005-5 has been written in 97.6882905960083
# File A005-6 has been written in 97.64518642425537
# File A005-7 has been written in 98.99090814590454
# File A005-8 has been written in 97.16513061523438
# File A005-9 has been written in 96.67616486549377
# File A005-10 has been written in 93.08828258514404
# File A005-11 has been written in 93.49610352516174
# File A005-12 has been written in 96.84772491455078
# File A005-13 has been written in 95.39007711410522
# File A005-14 has been written in 97.14506578445435
# File A005-15 has been written in 96.93736481666565
# File A005-16 has been written in 97.14350390434265
# File A005-17 has been written in 97.71215748786926
# File A005-18 has been written in 98.1542420387268
# File A005-19 has been written in 98.0071222782135
# File A005-20 has been written in 96.68344306945801
# File A005-21 has been written in 95.48296332359314
# File A005-22 has been written in 99.69399499893188
# File A005-23 has been written in 98.58734321594238
# File A005-24 has been written in 100.90746402740479
# File A005-25 has been written in 94.51575088500977
# File A005-26 has been written in 93.70236468315125
# File A005-27 has been written in 91.7687258720398
# File A005-28 has been written in 96.44234609603882
# Executing F3 csv_resample at 2017-08-15 04:35:20
# Column 1 has been resampled in 13.063862323760986
# Column 2 has been resampled in 11.981297969818115
# Column 3 has been resampled in 11.570051908493042
# Column 4 has been resampled in 12.599959373474121
# Column 5 has been resampled in 12.179866552352905
# Column 6 has been resampled in 12.382086038589478
# Column 7 has been resampled in 16.19119882583618
# Column 8 has been resampled in 10.875934839248657
# Column 9 has been resampled in 12.376479625701904
# Column 10 has been resampled in 11.634889602661133
# Column 11 has been resampled in 11.560141324996948
# Column 12 has been resampled in 11.839113473892212
# Column 13 has been resampled in 12.924515962600708
# Column 14 has been resampled in 12.435944080352783
# Column 15 has been resampled in 10.720062971115112
# Column 16 has been resampled in 12.679943799972534
# Column 17 has been resampled in 11.426796197891235
# Column 18 has been resampled in 12.24553918838501
# Column 19 has been resampled in 11.600635528564453
# Column 20 has been resampled in 11.680091381072998
# Column 21 has been resampled in 11.031874895095825
# Column 22 has been resampled in 11.738142013549805
# Column 23 has been resampled in 11.541831254959106
# Column 24 has been resampled in 11.26200795173645
# Column 25 has been resampled in 11.867401123046875
# Column 26 has been resampled in 12.925169706344604
# Column 27 has been resampled in 11.28580641746521
# Column 28 has been resampled in 12.077239990234375
# Asset A001 has been written in 338.33054065704346
# Column 1 has been resampled in 11.402918815612793
# Column 2 has been resampled in 12.69534182548523
# Column 3 has been resampled in 10.392206907272339
# Column 4 has been resampled in 11.73840618133545
# Column 5 has been resampled in 14.298771858215332
# Column 6 has been resampled in 11.980927228927612
# Column 7 has been resampled in 11.306581974029541
# Column 8 has been resampled in 11.844449043273926
# Column 9 has been resampled in 10.969778299331665
# Column 10 has been resampled in 11.846510887145996
# Column 11 has been resampled in 11.483512878417969
# Column 12 has been resampled in 11.164695978164673
# Column 13 has been resampled in 11.105373620986938
# Column 14 has been resampled in 10.699168920516968
# Column 15 has been resampled in 15.097055673599243
# Column 16 has been resampled in 16.62831687927246
# Column 17 has been resampled in 15.769609928131104
# Column 18 has been resampled in 14.148732423782349
# Column 19 has been resampled in 14.757357358932495
# Column 20 has been resampled in 11.260008573532104
# Column 21 has been resampled in 11.465840101242065
# Column 22 has been resampled in 13.816909313201904
# Column 23 has been resampled in 15.437576293945312
# Column 24 has been resampled in 15.492878198623657
# Column 25 has been resampled in 14.333104610443115
# Column 26 has been resampled in 14.950763463973999
# Column 27 has been resampled in 14.92997407913208
# Column 28 has been resampled in 14.88853144645691
# Asset A002 has been written in 366.44731163978577
# Column 1 has been resampled in 15.55135178565979
# Column 2 has been resampled in 16.524473905563354
# Column 3 has been resampled in 15.40945029258728
# Column 4 has been resampled in 14.396291732788086
# Column 5 has been resampled in 14.781216859817505
# Column 6 has been resampled in 14.240313291549683
# Column 7 has been resampled in 15.873474597930908
# Column 8 has been resampled in 16.78083848953247
# Column 9 has been resampled in 16.14336061477661
# Column 10 has been resampled in 15.741448640823364
# Column 11 has been resampled in 14.106310844421387
# Column 12 has been resampled in 15.496802568435669
# Column 13 has been resampled in 15.421164274215698
# Column 14 has been resampled in 13.932376384735107
# Column 15 has been resampled in 15.695812702178955
# Column 16 has been resampled in 14.776895761489868
# Column 17 has been resampled in 14.368166208267212
# Column 18 has been resampled in 18.58350133895874
# Column 19 has been resampled in 12.893450736999512
# Column 20 has been resampled in 14.375447988510132
# Column 21 has been resampled in 12.750595808029175
# Column 22 has been resampled in 15.96287727355957
# Column 23 has been resampled in 15.012192010879517
# Column 24 has been resampled in 14.44313097000122
# Column 25 has been resampled in 13.75194501876831
# Column 26 has been resampled in 14.47867727279663
# Column 27 has been resampled in 13.768412351608276
# Column 28 has been resampled in 14.439406871795654
# Asset A003 has been written in 420.5393981933594
# Column 1 has been resampled in 16.20128631591797
# Column 2 has been resampled in 15.22783637046814
# Column 3 has been resampled in 16.163431406021118
# Column 4 has been resampled in 14.882611274719238
# Column 5 has been resampled in 14.658711194992065
# Column 6 has been resampled in 15.210623025894165
# Column 7 has been resampled in 14.410351991653442
# Column 8 has been resampled in 14.501936197280884
# Column 9 has been resampled in 14.752959728240967
# Column 10 has been resampled in 15.00031566619873
# Column 11 has been resampled in 15.409465789794922
# Column 12 has been resampled in 16.07045340538025
# Column 13 has been resampled in 14.728465795516968
# Column 14 has been resampled in 16.306061029434204
# Column 15 has been resampled in 16.892815828323364
# Column 16 has been resampled in 12.84657096862793
# Column 17 has been resampled in 14.414557933807373
# Column 18 has been resampled in 14.952906131744385
# Column 19 has been resampled in 14.910361766815186
# Column 20 has been resampled in 15.189935207366943
# Column 21 has been resampled in 13.795695781707764
# Column 22 has been resampled in 14.617876291275024
# Column 23 has been resampled in 14.749042272567749
# Column 24 has been resampled in 14.073633432388306
# Column 25 has been resampled in 16.051210641860962
# Column 26 has been resampled in 15.591912508010864
# Column 27 has been resampled in 15.771353721618652
# Column 28 has been resampled in 13.823355436325073
# Asset A004 has been written in 421.7647008895874
# Column 1 has been resampled in 14.717554092407227
# Column 2 has been resampled in 13.934240102767944
# Column 3 has been resampled in 14.447056293487549
# Column 4 has been resampled in 14.438103437423706
# Column 5 has been resampled in 13.950405359268188
# Column 6 has been resampled in 14.862048387527466
# Column 7 has been resampled in 14.137501001358032
# Column 8 has been resampled in 14.097764015197754
# Column 9 has been resampled in 14.27349042892456
# Column 10 has been resampled in 15.092853307723999
# Column 11 has been resampled in 15.451713800430298
# Column 12 has been resampled in 15.415472745895386
# Column 13 has been resampled in 12.441897869110107
# Column 14 has been resampled in 12.891692876815796
# Column 15 has been resampled in 11.064517259597778
# Column 16 has been resampled in 12.557971715927124
# Column 17 has been resampled in 14.210022687911987
# Column 18 has been resampled in 14.931960105895996
# Column 19 has been resampled in 14.722471475601196
# Column 20 has been resampled in 14.267120599746704
# Column 21 has been resampled in 13.763165950775146
# Column 22 has been resampled in 14.686262130737305
# Column 23 has been resampled in 14.37111520767212
# Column 24 has been resampled in 14.91248607635498
# Column 25 has been resampled in 14.398382902145386
# Column 26 has been resampled in 15.801119565963745
# Column 27 has been resampled in 14.250930547714233
# Column 28 has been resampled in 15.59597659111023
# Asset A005 has been written in 400.234965801239
# Executing F4: all_in_one_csv at 2017-08-15 05:07:48
# File datasets10Min.csv has been written in 4.583834648132324

# %%
df
# Out:
#            asset  WGDCTrafoPhase1Temp  WHDRGroupOilPress  WGDCTrafoPhase3Temp  \
# date_time
# 1430439000  A001             0.541919           0.946188             0.541306
# 1430439600  A001             0.541524           0.947391             0.539759
# 1430440200  A001             0.541172           0.945406             0.539249
# 1430440800  A001             0.541923           0.946720             0.539951
# 1430441400  A001             0.543004           0.946798             0.539871
# 1430442000  A001             0.542826           0.949098             0.539371
# 1430442600  A001             0.544050           0.950024             0.541913
# 1430443200  A001             0.546805           0.944836             0.545194
# 1430443800  A001             0.549281           0.948360             0.547869
# 1430444400  A001             0.550588           0.951473             0.549293
# 1430445000  A001             0.550304           0.946406             0.548833
# 1430445600  A001             0.550432           0.943588             0.548365
# 1430446200  A001             0.550962           0.947580             0.547880
# 1430446800  A001             0.548482           0.949515             0.546201
# 1430447400  A001             0.545282           0.945944             0.541779
# 1430448000  A001             0.542184           0.946237             0.538436
# 1430448600  A001             0.538868           0.948417             0.535221
# 1430449200  A001             0.535031           0.946847             0.531478
# 1430449800  A001             0.531430           0.946561             0.528081
# 1430450400  A001             0.528868           0.949795             0.525792
# 1430451000  A001             0.527134           0.946712             0.524346
# 1430451600  A001             0.524323           0.948881             0.521551
# 1430452200  A001             0.523064           0.947753             0.520189
# 1430452800  A001             0.521492           0.947033             0.519950
# 1430453400  A001             0.519946           0.947903             0.518758
# 1430454000  A001             0.518819           0.946873             0.516106
# 1430454600  A001             0.516692           0.949600             0.514075
# 1430455200  A001             0.514083           0.947102             0.511309
# 1430455800  A001             0.511660           0.946099             0.509001
# 1430456400  A001             0.509520           0.947625             0.506560
# ...          ...                  ...                ...                  ...
# 1433099400  A005             0.589176           0.945303             0.603596
# 1433100000  A005             0.589727           0.945616             0.604360
# 1433100600  A005             0.590538           0.945440             0.605113
# 1433101200  A005             0.591101           0.950008             0.605840
# 1433101800  A005             0.592851           0.947448             0.607080
# 1433102400  A005             0.594558           0.948241             0.608476
# 1433103000  A005             0.595687           0.946930             0.609698
# 1433103600  A005             0.596460           0.947221             0.610721
# 1433104200  A005             0.597362           0.948714             0.611693
# 1433104800  A005             0.599350           0.947676             0.613373
# 1433105400  A005             0.601064           0.947719             0.615124
# 1433106000  A005             0.602354           0.949182             0.616366
# 1433106600  A005             0.603552           0.947718             0.617403
# 1433107200  A005             0.605117           0.947642             0.619020
# 1433107800  A005             0.607000           0.945793             0.621250
# 1433108400  A005             0.609418           0.949324             0.623961
# 1433109000  A005             0.611843           0.947314             0.626552
# 1433109600  A005             0.615302           0.946244             0.630625
# 1433110200  A005             0.618483           0.946993             0.633799
# 1433110800  A005             0.619119           0.946812             0.633898
# 1433111400  A005             0.618235           0.947273             0.633120
# 1433112000  A005             0.618450           0.947184             0.633050
# 1433112600  A005             0.584397           0.946972             0.598597
# 1433113200  A005             0.490799           0.946828             0.503866
# 1433113800  A005             0.491530           0.946405             0.503854
# 1433114400  A005             0.491511           0.947555             0.504064
# 1433115000  A005             0.491992           0.946203             0.504496
# 1433115600  A005             0.491778           0.945193             0.504536
# 1433116200  A005             0.492310           0.947670             0.503914
# 1433116800  A005             0.491728           0.944163             0.503850
#
#             WTURReactivePower  WROTPitchAngleSP  WNACDirection  \
# date_time
# 1430439000           0.464225          0.023942       0.632365
# 1430439600           0.463898          0.023304       0.636720
# 1430440200           0.463815          0.024484       0.636720
# 1430440800           0.464394          0.023037       0.636720
# 1430441400           0.465152          0.022420       0.636720
# 1430442000           0.464601          0.023623       0.626815
# 1430442600           0.465144          0.022882       0.632886
# 1430443200           0.466300          0.024797       0.635254
# 1430443800           0.466289          0.021422       0.608510
# 1430444400           0.467629          0.022245       0.608510
# 1430445000           0.465802          0.024684       0.608510
# 1430445600           0.465336          0.022776       0.608510
# 1430446200           0.464935          0.023207       0.608510
# 1430446800           0.467645          0.023303       0.608510
# 1430447400           0.469160          0.023500       0.608510
# 1430448000           0.469718          0.022606       0.585986
# 1430448600           0.469961          0.022970       0.608510
# 1430449200           0.469849          0.023118       0.608510
# 1430449800           0.467972          0.023764       0.608510
# 1430450400           0.465796          0.022976       0.608510
# 1430451000           0.468349          0.023655       0.608510
# 1430451600           0.465514          0.023415       0.608510
# 1430452200           0.464886          0.022832       0.608510
# 1430452800           0.465432          0.023108       0.608510
# 1430453400           0.466716          0.023590       0.608510
# 1430454000           0.467756          0.024643       0.608510
# 1430454600           0.468675          0.023549       0.596061
# 1430455200           0.470434          0.022130       0.596790
# 1430455800           0.472433          0.022786       0.576854
# 1430456400           0.473237          0.023202       0.573780
# ...                       ...               ...            ...
# 1433099400           0.481421          0.038470       0.851130
# 1433100000           0.482653          0.036562       0.842412
# 1433100600           0.482884          0.037508       0.823608
# 1433101200           0.478966          0.029011       0.849992
# 1433101800           0.477453          0.022549       0.870230
# 1433102400           0.478406          0.023564       0.870230
# 1433103000           0.480307          0.025022       0.870230
# 1433103600           0.479965          0.026990       0.870230
# 1433104200           0.476508          0.022845       0.877054
# 1433104800           0.473080          0.023002       0.893660
# 1433105400           0.474594          0.021732       0.893660
# 1433106000           0.476830          0.022281       0.893660
# 1433106600           0.476323          0.023890       0.893660
# 1433107200           0.470761          0.023042       0.893660
# 1433107800           0.467497          0.022925       0.893660
# 1433108400           0.468164          0.022890       0.900957
# 1433109000           0.466873          0.021673       0.924050
# 1433109600           0.466507          0.021174       0.940356
# 1433110200           0.470848          0.023987       0.947480
# 1433110800           0.472041          0.032554       0.934296
# 1433111400           0.471586          0.027763       0.019100
# 1433112000           0.472086          0.026484       0.030364
# 1433112600           0.474769          0.022091       0.190162
# 1433113200           0.477917          0.027764       0.634906
# 1433113800           0.476996          0.030825       0.656680
# 1433114400           0.478920          0.028466       0.656680
# 1433115000           0.479792          0.028663       0.656680
# 1433115600           0.480705          0.034852       0.677752
# 1433116200           0.482790          0.041434       0.666217
# 1433116800           0.484210          0.040501       0.728080
#
#             WGENPhase2Temp  WYAWPressure  WTURReactivePowerAux  \
# date_time
# 1430439000        0.678605      0.968385              0.496401
# 1430439600        0.674164      1.006540              0.496439
# 1430440200        0.671611      1.006919              0.496417
# 1430440800        0.675750      1.007420              0.496524
# 1430441400        0.667582      1.007043              0.496735
# 1430442000        0.667339      0.969363              0.496522
# 1430442600        0.680786      0.949568              0.496371
# 1430443200        0.693518      0.944370              0.496279
# 1430443800        0.696775      1.005361              0.496513
# 1430444400        0.699589      1.007010              0.496516
# 1430445000        0.691600      1.007334              0.496543
# 1430445600        0.687579      1.007085              0.496769
# 1430446200        0.683658      1.006370              0.496664
# 1430446800        0.669744      1.007133              0.496722
# 1430447400        0.655651      1.006885              0.496850
# 1430448000        0.642844      0.911817              0.496605
# 1430448600        0.633750      1.001806              0.496813
# 1430449200        0.625806      1.005350              0.496793
# 1430449800        0.618075      1.005899              0.496829
# 1430450400        0.613001      1.005741              0.496846
# 1430451000        0.608011      1.005986              0.496776
# 1430451600        0.602025      1.005715              0.496795
# 1430452200        0.599730      1.005641              0.496704
# 1430452800        0.604228      1.006273              0.496487
# 1430453400        0.600724      1.007374              0.496696
# 1430454000        0.596284      1.006719              0.496807
# 1430454600        0.593046      0.930999              0.496667
# 1430455200        0.590156      1.002897              0.496815
# 1430455800        0.586101      0.963594              0.496724
# 1430456400        0.583634      1.005120              0.496807
# ...                    ...           ...                   ...
# 1433099400        0.603495      0.994989              0.496941
# 1433100000        0.606071      0.961368              0.496793
# 1433100600        0.608072      0.897551              0.496872
# 1433101200        0.609551      0.943282              0.496913
# 1433101800        0.611829      0.997954              0.496902
# 1433102400        0.610964      0.999091              0.496822
# 1433103000        0.609620      0.998726              0.496846
# 1433103600        0.608790      0.998574              0.496893
# 1433104200        0.609174      0.961101              0.496744
# 1433104800        0.607115      0.998234              0.496823
# 1433105400        0.604705      0.998827              0.496888
# 1433106000        0.603033      0.999488              0.496857
# 1433106600        0.601283      0.998832              0.496829
# 1433107200        0.597867      0.998731              0.496827
# 1433107800        0.594184      0.999029              0.496865
# 1433108400        0.592051      0.953390              0.496743
# 1433109000        0.593145      0.997784              0.496859
# 1433109600        0.605306      0.960057              0.496406
# 1433110200        0.603404      0.998162              0.496683
# 1433110800        0.596476      0.894014              0.496560
# 1433111400        0.593931      0.997320              0.496780
# 1433112000        0.593393      0.976702              0.496705
# 1433112600        0.584520      0.998709              0.496785
# 1433113200        0.563559      0.955866              0.496743
# 1433113800        0.565524      0.997509              0.496686
# 1433114400        0.567001      0.998741              0.496805
# 1433115000        0.568685      0.999647              0.496742
# 1433115600        0.569316      0.861776              0.496628
# 1433116200        0.568870      0.960416              0.496936
# 1433116800        0.567713      0.835613              0.496588
#
#                   ...          WHDRGroupOilTemp  WNACAmbTemp  WCNVCosPhi  \
# date_time         ...
# 1430439000        ...                  0.499482     0.352273    0.987495
# 1430439600        ...                  0.500185     0.348559    0.988017
# 1430440200        ...                  0.501745     0.345775    0.988010
# 1430440800        ...                  0.501841     0.343308    0.988437
# 1430441400        ...                  0.502408     0.340779    0.985260
# 1430442000        ...                  0.501199     0.343089    0.989713
# 1430442600        ...                  0.501477     0.342769    0.992758
# 1430443200        ...                  0.501490     0.339114    0.993795
# 1430443800        ...                  0.502600     0.336033    0.991575
# 1430444400        ...                  0.503294     0.336037    0.992075
# 1430445000        ...                  0.503062     0.335432    0.988807
# 1430445600        ...                  0.502637     0.332393    0.989080
# 1430446200        ...                  0.503936     0.328997    0.988673
# 1430446800        ...                  0.503291     0.325861    0.974722
# 1430447400        ...                  0.503516     0.323866    0.962533
# 1430448000        ...                  0.503212     0.322143    0.976577
# 1430448600        ...                  0.501507     0.320483    0.962802
# 1430449200        ...                  0.500008     0.319497    0.962517
# 1430449800        ...                  0.499772     0.318959    0.965877
# 1430450400        ...                  0.498659     0.318964    0.978693
# 1430451000        ...                  0.497653     0.316402    0.967687
# 1430451600        ...                  0.495850     0.317558    0.978545
# 1430452200        ...                  0.494112     0.317291    0.982332
# 1430452800        ...                  0.493139     0.315365    0.982735
# 1430453400        ...                  0.492676     0.313199    0.972632
# 1430454000        ...                  0.491367     0.313898    0.977272
# 1430454600        ...                  0.490154     0.315267    0.955890
# 1430455200        ...                  0.489843     0.314620    0.962272
# 1430455800        ...                  0.488525     0.312476    0.969442
# 1430456400        ...                  0.488691     0.310927    0.969008
# ...               ...                       ...          ...         ...
# 1433099400        ...                  0.629770     0.513263    0.562070
# 1433100000        ...                  0.628959     0.512257    0.727563
# 1433100600        ...                  0.628747     0.509257    0.712942
# 1433101200        ...                  0.629108     0.501671    0.829113
# 1433101800        ...                  0.632417     0.495531    0.966348
# 1433102400        ...                  0.635103     0.497464    0.959977
# 1433103000        ...                  0.637773     0.497477    0.932715
# 1433103600        ...                  0.639964     0.497566    0.918325
# 1433104200        ...                  0.640871     0.491520    0.948088
# 1433104800        ...                  0.641670     0.485100    0.976745
# 1433105400        ...                  0.641774     0.486941    0.970768
# 1433106000        ...                  0.643186     0.483776    0.962307
# 1433106600        ...                  0.643230     0.476959    0.965512
# 1433107200        ...                  0.643230     0.466942    0.977415
# 1433107800        ...                  0.643230     0.451053    0.981393
# 1433108400        ...                  0.642655     0.441931    0.984077
# 1433109000        ...                  0.641613     0.436883    0.988040
# 1433109600        ...                  0.639618     0.426018    0.990418
# 1433110200        ...                  0.637449     0.413242    0.975868
# 1433110800        ...                  0.635069     0.393632    0.832122
# 1433111400        ...                  0.633888     0.371107    0.865217
# 1433112000        ...                  0.631581     0.364669    0.904178
# 1433112600        ...                  0.593835     0.324501    0.947087
# 1433113200        ...                  0.495134     0.227115    0.935288
# 1433113800        ...                  0.493275     0.222677    0.902028
# 1433114400        ...                  0.494909     0.217522    0.923610
# 1433115000        ...                  0.496874     0.211201    0.922412
# 1433115600        ...                  0.498310     0.204503    0.823998
# 1433116200        ...                  0.498310     0.198742    0.680502
# 1433116800        ...                  0.496399     0.194963    0.689123
#
#             WTURPowerAux  WGENGenSpeed  WGENPhase1Temp  WCNVNetVoltage  \
# date_time
# 1430439000     -0.006425      0.925665        0.670345       62.760000
# 1430439600     -0.006494      0.929502        0.665521       62.814865
# 1430440200     -0.006485      0.932675        0.662782       62.831740
# 1430440800     -0.006270      0.932404        0.666791       62.902396
# 1430441400     -0.005621      0.902527        0.658676       62.843958
# 1430442000     -0.006215      0.936153        0.658395       62.718656
# 1430442600     -0.006579      0.955589        0.672140       62.546469
# 1430443200     -0.006807      0.957790        0.684996       62.576073
# 1430443800     -0.006369      0.947210        0.688212       62.535969
# 1430444400     -0.006403      0.947601        0.690857       62.381427
# 1430445000     -0.006403      0.928778        0.682724       62.334698
# 1430445600     -0.005756      0.934908        0.678863       62.424156
# 1430446200     -0.005959      0.930291        0.675026       62.350438
# 1430446800     -0.005831      0.806641        0.661475       62.553250
# 1430447400     -0.005515      0.744528        0.647585       62.475344
# 1430448000     -0.005891      0.805645        0.634730       62.609427
# 1430448600     -0.005494      0.736438        0.625666       62.810958
# 1430449200     -0.005653      0.737375        0.617974       62.725062
# 1430449800     -0.005543      0.765191        0.610331       62.632563
# 1430450400     -0.005479      0.855331        0.605312       62.628125
# 1430451000     -0.005537      0.766978        0.600291       62.852833
# 1430451600     -0.005473      0.844891        0.594341       62.842208
# 1430452200     -0.005705      0.879444        0.591836       62.936885
# 1430452800     -0.006273      0.883102        0.596039       62.986625
# 1430453400     -0.005759      0.805203        0.592752       63.029906
# 1430454000     -0.005498      0.825180        0.588348       62.887125
# 1430454600     -0.005689      0.736524        0.585241       62.872833
# 1430455200     -0.005463      0.742475        0.582066       62.717510
# 1430455800     -0.005680      0.745777        0.578674       62.801062
# 1430456400     -0.005478      0.730422        0.576059       62.971344
# ...                  ...           ...             ...             ...
# 1433099400     -0.005273      0.600055        0.614332       62.942354
# 1433100000     -0.005631      0.600007        0.617007       62.718406
# 1433100600     -0.005363      0.599950        0.619001       62.578063
# 1433101200     -0.005370      0.634111        0.620369       62.459656
# 1433101800     -0.005638      0.681631        0.622456       62.224292
# 1433102400     -0.005769      0.656111        0.621638       62.615917
# 1433103000     -0.005567      0.600599        0.620329       62.831281
# 1433103600     -0.005543      0.600018        0.619629       62.547177
# 1433104200     -0.005861      0.656391        0.619961       62.475688
# 1433104800     -0.005714      0.770715        0.617458       62.403740
# 1433105400     -0.005579      0.725581        0.614752       62.402198
# 1433106000     -0.005618      0.675146        0.613383       62.552750
# 1433106600     -0.005588      0.688650        0.611559       62.866354
# 1433107200     -0.005659      0.794558        0.607859       62.640094
# 1433107800     -0.005522      0.850509        0.603554       62.637635
# 1433108400     -0.005669      0.863148        0.600715       62.573156
# 1433109000     -0.005493      0.916845        0.601639       62.576969
# 1433109600     -0.006489      0.950893        0.614014       62.867010
# 1433110200     -0.005854      0.800878        0.611854       62.936146
# 1433110800     -0.005925      0.600538        0.605831       62.755062
# 1433111400     -0.005615      0.656134        0.603370       62.958802
# 1433112000     -0.005779      0.617361        0.602892       63.046375
# 1433112600     -0.005621      0.655770        0.593762       63.410292
# 1433113200     -0.005343      0.614350        0.571999       64.051698
# 1433113800     -0.005621      0.603543        0.574151       63.869833
# 1433114400     -0.005265      0.602572        0.575634       64.087958
# 1433115000     -0.005439      0.601861        0.577400       64.142969
# 1433115600     -0.005430      0.599976        0.577956       63.893969
# 1433116200     -0.005052      0.599912        0.577333       63.604635
# 1433116800     -0.005480      0.599979        0.576153       63.767063
#
#             WNACNacelleTemp  WTURPower  WNACWindDirection
# date_time
# 1430439000         0.564973   0.484594           0.034610
# 1430439600         0.562886   0.499054          -0.193071
# 1430440200         0.563298   0.498477          -0.063975
# 1430440800         0.558239   0.500386          -0.217021
# 1430441400         0.571563   0.429755          -0.159086
# 1430442000         0.565492   0.541194          -0.102420
# 1430442600         0.555453   0.622016          -0.000300
# 1430443200         0.549729   0.657989          -0.072638
# 1430443800         0.551172   0.565881           0.184530
# 1430444400         0.552306   0.551527           0.034301
# 1430445000         0.554407   0.489539           0.025224
# 1430445600         0.557888   0.494026          -0.208111
# 1430446200         0.557665   0.499702          -0.071030
# 1430446800         0.559012   0.305428          -0.116738
# 1430447400         0.567308   0.231973          -0.145549
# 1430448000         0.567109   0.301167           0.079833
# 1430448600         0.569137   0.225587          -0.074899
# 1430449200         0.569514   0.224837           0.024999
# 1430449800         0.565937   0.253184           0.086086
# 1430450400         0.564734   0.367381           0.058847
# 1430451000         0.562486   0.256431          -0.122705
# 1430451600         0.561780   0.343083           0.010217
# 1430452200         0.561760   0.396907           0.088521
# 1430452800         0.546371   0.404193           0.168494
# 1430453400         0.551757   0.305130           0.067638
# 1430454000         0.557145   0.326618           0.047601
# 1430454600         0.555851   0.231236          -0.006960
# 1430455200         0.554184   0.229999          -0.044756
# 1430455800         0.556806   0.235536          -0.013872
# 1430456400         0.556713   0.218288           0.026919
# ...                     ...        ...                ...
# 1433099400         0.823205   0.030432          -0.028033
# 1433100000         0.828409   0.044016          -0.201090
# 1433100600         0.826538   0.041095          -0.057494
# 1433101200         0.809752   0.103877           0.172130
# 1433101800         0.821757   0.171001           0.055783
# 1433102400         0.818210   0.153378          -0.018902
# 1433103000         0.822291   0.103934           0.139229
# 1433103600         0.825670   0.092940           0.181645
# 1433104200         0.819119   0.151301           0.177839
# 1433104800         0.806214   0.254377           0.155125
# 1433105400         0.801171   0.210963           0.094954
# 1433106000         0.797642   0.166073          -0.055794
# 1433106600         0.790605   0.176153          -0.187905
# 1433107200         0.781243   0.277212          -0.000743
# 1433107800         0.773940   0.343739           0.087685
# 1433108400         0.764601   0.359744           0.139222
# 1433109000         0.751782   0.442220          -0.025109
# 1433109600         0.763375   0.500005          -0.024035
# 1433110200         0.759684   0.305617           0.014576
# 1433110800         0.757135   0.091065           0.212236
# 1433111400         0.743158   0.131427           0.203010
# 1433112000         0.742973   0.123981           0.035089
# 1433112600         0.674344   0.151141           0.142740
# 1433113200         0.521467   0.121404           0.143596
# 1433113800         0.510072   0.102733           0.196573
# 1433114400         0.517666   0.104467          -0.020801
# 1433115000         0.504972   0.101548           0.012173
# 1433115600         0.498605   0.063578          -0.102995
# 1433116200         0.485892   0.035864           0.208140
# 1433116800         0.488406   0.032172           0.232951
#
# [22320 rows x 29 columns]
